# %%
import pandas as pd
import requests

# %%
access_key = "46664f6c5367656f3133334552666a4f"
access_url = "http://openapi.seoul.go.kr:8088/"

url = access_url + access_key +"/json/tbLnOpendataRtmsV/1/200/2023"
res = requests.get(url)
response = res.json()

# %%
print(response['tbLnOpendataRtmsV']['row'])
# Out:
# [{'ACC_YEAR': '2023', 'SGG_CD': '11710', 'SGG_NM': '송파구', 'BJDONG_CD': '10800', 'BJDONG_NM': '문정동', 'LAND_GBN': '1', 'LAND_GBN_NM': '대지', 'BONBEON': '0652', 'BUBEON': '0004', 'BLDG_NM': '힐스테이트에코문정', 'DEAL_YMD': '20230805', 'OBJ_AMT': '20500', 'BLDG_AREA': 20.79, 'TOT_AREA': 32.68, 'FLOOR': 4.0, 'RIGHT_GBN': '', 'CNTL_YMD': '', 'BUILD_YEAR': '2018', 'HOUSE_TYPE': '오피스텔', 'REQ_GBN': '중개거래', 'RDEALER_LAWDNM': '서울 송파구'}, {'ACC_YEAR': '2023', 'SGG_CD': '11620', 'SGG_NM': '관악구', 'BJDONG_CD': '10100', 'BJDONG_NM': '봉천동', 'LAND_GBN': '1', 'LAND_GBN_NM': '대지', 'BONBEON': '0715', 'BUBEON': '0185', 'BLDG_NM': '(715-185)', 'DEAL_YMD': '20230804', 'OBJ_AMT': '15000', 'BLDG_AREA': 41.06, 'TOT_AREA': 31.3, 'FLOOR': 1.0, 'RIGHT_GBN': '', 'CNTL_YMD': '', 'BUILD_YEAR': '1988', 'HOUSE_TYPE': '연립다세대', 'REQ_GBN': '직거래', 'RDEALER_LAWDNM': ''}, {'ACC_YEAR': '2023', 'SGG_CD': '11500', 'SGG_NM': '강서구', 'BJDONG_CD': '10300', 'BJDONG_NM': '화곡동', 'LAND_GBN': '1', 'LAND_GBN_NM': '대지', 'BONBEON': '0338', 'BUBEON'
# ...

# %%
df = pd.DataFrame(response['tbLnOpendataRtmsV']['row'])
df
# Out:
#     ACC_YEAR SGG_CD SGG_NM BJDONG_CD BJDONG_NM LAND_GBN LAND_GBN_NM BONBEON  \
# 0       2023  11710    송파구     10800       문정동        1          대지    0652
# 1       2023  11620    관악구     10100       봉천동        1          대지    0715
# 2       2023  11500    강서구     10300       화곡동        1          대지    0338
# 3       2023  11740    강동구     10300       상일동        1          대지    0514
# 4       2023  11440    마포구     12500       성산동        1          대지    0593
# ..       ...    ...    ...       ...       ...      ...         ...     ...
# 195     2023  11380    은평구     10700       응암동        1          대지    0587
# 196     2023  11260    중랑구     10300       중화동        1          대지    0208
# 197     2023  11380    은평구     10500       구산동        1          대지    0183
# 198     2023  11410   서대문구     11100       홍제동        1          대지    0122
# 199     2023  11740    강동구     10200       고덕동        1          대지    0523
#
# ...

# %%
df = df.drop(columns=['SGG_CD', 'BJDONG_CD', 'LAND_GBN', 'RIGHT_GBN', 'LAND_GBN_NM', 'BONBEON', 'BUBEON', 'CNTL_YMD'])
df
# Out:
#     ACC_YEAR SGG_NM BJDONG_NM      BLDG_NM  DEAL_YMD OBJ_AMT  BLDG_AREA  \
# 0       2023    송파구       문정동    힐스테이트에코문정  20230805   20500      20.79
# 1       2023    관악구       봉천동    (715-185)  20230804   15000      41.06
# 2       2023    강서구       화곡동       가이아팰리스  20230804   26750      29.99
# 3       2023    강동구       상일동   고덕롯데캐슬베네루체  20230804  105000      59.98
# 4       2023    마포구       성산동  상암 수린나 오피스텔  20230804   16500      17.55
# ..       ...    ...       ...          ...       ...     ...        ...
# 195     2023    은평구       응암동        백영빌라트  20230731   26000      55.21
# 196     2023    중랑구       중화동        범양프레체  20230731   11400      17.94
# 197     2023    은평구       구산동   파크원(183-1)  20230731   24750      38.38
# 198     2023   서대문구       홍제동     (122-25)  20230731   28000      35.56
# 199     2023    강동구       고덕동      (523-0)  20230731   50000      50.34
#
#      TOT_AREA  FLOOR BUILD_YEAR HOUSE_TYPE REQ_GBN RDEALER_LAWDNM
# ...
